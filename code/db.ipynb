# %%
import sqlite3, json, os
import pandas as pd

DATA_OUTPUT_PATH = '../data/out'
PATH_JSON = os.path.join(DATA_OUTPUT_PATH,'outputs','data.json')
OUTPUT_DB = os.path.join(DATA_OUTPUT_PATH,'outputs','database.db')
OUTPUT_CSV = os.path.join(DATA_OUTPUT_PATH,'outputs','data.csv')

with open(PATH_JSON, 'r') as file:
    data_json = json.load(file)

conn = sqlite3.connect(OUTPUT_DB)
cursor = conn.cursor()

# Criar tabela
cursor.execute('''
    CREATE TABLE IF NOT EXISTS tree_data (
        tree_name TEXT,
        subtree_name TEXT,
        terminal_list TEXT,
        list_terminals_hash INTEGER,
        terminal_data TEXT
    )
''')

# Inserir dados do JSON no banco de dados
for data in data_json:
    for tree_name, inner_data in data.items():
        for inner_name, inner_details in inner_data.items():
            terminal_list = json.dumps(inner_details['Terminals'])
            terminal_data = json.dumps(inner_details['data_terminals'])

            cursor.execute('''
                INSERT INTO tree_data (tree_name, subtree_name, terminal_list, list_terminals_hash, terminal_data)
                VALUES (?, ?, ?, ?, ?)
            ''', (tree_name, inner_name, terminal_list, inner_details['List_terminals_hash'], terminal_data))

conn.commit()

print("\n\nDados inseridos no banco de dados.")
# Out:
# Dados inseridos no banco de dados.

# %%
# Executar uma consulta SQL para selecionar todos os dados da tabela
consulta_sql = 'SELECT * FROM tree_data'
cursor.execute(consulta_sql)

# Obter os resultados da consulta e carregar em um DataFrame do pandas
dados_df = pd.read_sql_query(consulta_sql, conn)

# Fechar a conexão com o banco de dados
conn.close()

# Exibir o DataFrame (tabela) usando pandas
dados_df.to_csv(OUTPUT_CSV)
dados_df
# Out:
#                tree_name               subtree_name  \
# 0      tree_ORTHOMCL1007   tree_ORTHOMCL1007_Inner4
# 1      tree_ORTHOMCL1007   tree_ORTHOMCL1007_Inner3
# 2      tree_ORTHOMCL1007   tree_ORTHOMCL1007_Inner2
# 3      tree_ORTHOMCL1007   tree_ORTHOMCL1007_Inner1
# 4      tree_ORTHOMCL1895   tree_ORTHOMCL1895_Inner3
# ...                  ...                        ...
# 7737  tree_ORTHOMCL256_2  tree_ORTHOMCL256_2_Inner5
# 7738  tree_ORTHOMCL256_2  tree_ORTHOMCL256_2_Inner3
# 7739  tree_ORTHOMCL256_2  tree_ORTHOMCL256_2_Inner2
# 7740  tree_ORTHOMCL256_2  tree_ORTHOMCL256_2_Inner1
# 7741  tree_ORTHOMCL256_2  tree_ORTHOMCL256_2_Inner4
#
#                      terminal_list  list_terminals_hash  \
# 0      [213, 79, 135, 196, 85, 10]                  102
# 1                   [213, 79, 135]                  119
# 2                        [213, 79]                  195
# 3                         [85, 10]                  156
# 4          [248, 2, 186, 170, 115]                   81
# ...                            ...                  ...
# 7737  [186, 141, 218, 59, 178, 21]                   50
# 7738           [186, 141, 218, 59]                   16
# 7739                [141, 218, 59]                   49
# 7740                     [218, 59]                   41
# 7741                     [178, 21]                  229
#
#                                           terminal_data
# 0     [{"newick": "4lcl|XP_812269.1", "terrminal_has...
# 1     [{"newick": "4lcl|XP_812269.1", "terrminal_has...
# 2     [{"newick": "4lcl|XP_812269.1", "terrminal_has...
# 3     [{"newick": "1lcl|AAN35877.1", "terrminal_hash...
# 4     [{"newick": "4lcl|XP_820341.1", "terrminal_has...
# ...                                                 ...
# 7737  [{"newick": "2lcl|CAD51724.1", "terminal_hash"...
# 7738  [{"newick": "2lcl|CAD51724.1", "terminal_hash"...
# 7739  [{"newick": "6lcl|XP_657212.1", "terminal_hash...
# 7740  [{"newick": "5lcl|XP_656669.1", "terminal_hash...
# 7741  [{"newick": "1lcl|AAZ14427.1", "terminal_hash"...
#
# [7742 rows x 5 columns]
